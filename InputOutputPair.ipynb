# %%
# # import sys
# # !{sys.executable} -m pip install tiktoken
# import tiktoken

# %%
import tiktoken

# %%
with open("the-verdict.txt", "r", encoding="utf-8") as f:
    raw_text = f.read()

tokenizer = tiktoken.get_encoding("gpt2")
enc_text = tokenizer.encode(raw_text)
print(len(enc_text))
# Out:
# 5145

# %%
enc_sample = enc_text[:50]

# %%
print(enc_sample)
# Out:
# [40, 367, 2885, 1464, 1807, 3619, 402, 271, 10899, 2138, 257, 7026, 15632, 438, 2016, 257, 922, 5891, 1576, 438, 568, 340, 373, 645, 1049, 5975, 284, 502, 284, 3285, 326, 11, 287, 262, 6001, 286, 465, 13476, 11, 339, 550, 5710, 465, 12036, 11, 6405, 257, 5527, 27075, 11]

# %%
context_size = 4

x = enc_sample[:context_size]
y = enc_sample[1:context_size+1]

print(f"x: {x}")
print(f"y:     {y}")
# Out:
# x: [40, 367, 2885, 1464]
# y:     [367, 2885, 1464, 1807]

# %%
for i in range(1, context_size+1):
    context = enc_sample[:i]
    desired = enc_sample[i]

    print(context, "------>", desired)
# Out:
# [40] ------> 367
# [40, 367] ------> 2885
# [40, 367, 2885] ------> 1464
# [40, 367, 2885, 1464] ------> 1807

# %%
for i in range(1, context_size+1):
    context = enc_sample[:i]
    desired = enc_sample[i]

    print(tokenizer.decode(context), "------>", tokenizer.decode([desired]))
# Out:
# I ------>  H
# I H ------> AD
# I HAD ------>  always
# I HAD always ------>  thought

# %% [markdown]
# <h1>Implement a Data Loader</h1>

# %%
pip install torch torchvision torchaudio
# Out:
# Collecting torch
#   Downloading torch-2.10.0-cp310-none-macosx_11_0_arm64.whl.metadata (31 kB)
# Collecting torchvision
#   Downloading torchvision-0.25.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.4 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.10.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.9 kB)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/labelme_env/lib/python3.10/site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/envs/labelme_env/lib/python3.10/site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/envs/labelme_env/lib/python3.10/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/envs/labelme_env/lib/python3.10/site-packages (from torch) (3.4.2)
# Collecting jinja2 (from torch)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=0.8.5 (from torch)
#   Using cached fsspec-2026.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/labelme_env/lib/python3.10/site-packages (from torchvision) (1.23.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/anaconda3/envs/labelme_env/lib/python3.10/site-packages (from torchvision) (12.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/labelme_env/lib/python3.10/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Using cached markupsafe-3.0.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Downloading torch-2.10.0-cp310-none-macosx_11_0_arm64.whl (79.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.4/79.4 MB 28.6 MB/s  0:00:02m0:00:0100:01
# Downloading torchvision-0.25.0-cp310-cp310-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 19.5 MB/s  0:00:00
# Downloading torchaudio-2.10.0-cp310-cp310-macosx_11_0_arm64.whl (734 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 734.9/734.9 kB 21.4 MB/s  0:00:00
# Using cached fsspec-2026.1.0-py3-none-any.whl (201 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached markupsafe-3.0.3-cp310-cp310-macosx_11_0_arm64.whl (12 kB)
# Installing collected packages: MarkupSafe, fsspec, jinja2, torch, torchvision, torchaudio
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [torchaudio]6 [torchvision]
# Successfully installed MarkupSafe-3.0.3 fsspec-2026.1.0 jinja2-3.1.6 torch-2.10.0 torchaudio-2.10.0 torchvision-0.25.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from torch.utils.data import Dataset, DataLoader
# max_length = context size
# tokenizer = bpe
# txt = dataset
# stride = jump (slide)

class GPTDatasetV1(Dataset):
    def __init__(self, txt, tokenizer, max_length, stride):
        self.input_ids = []
        self.target_ids = []

        token_ids = tokenizer.encode(txt, allowed_special = {"<|endoftext|>"})

        for i in range(0, len(token_ids) - max_length, stride):
            input_chunk = token_ids[i:i + max_length]
            target_chunk = token_ids[i+1: i+max_length+1]
            self.input_ids.append(torch.tensor(input_chunk))
            self.target_ids.append(torch.tensor(target_chunk))

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self,idx):
        return self.input_ids[idx], self.target_ids[idx]

# %%
def create_dataloader_v1(txt, batch_size = 4, max_length = 256, stride = 128, shuffle = True, drop_last = True, num_workers = 0):
    tokenizer = tiktoken.get_encoding("gpt2")

    dataset = GPTDatasetV1(txt, tokenizer, max_length, stride)

    dataloader = DataLoader(
        dataset,
        batch_size = batch_size,
        shuffle = shuffle,
        drop_last = drop_last,
        num_workers = num_workers
    )

    return dataloader

# %%
with open("the-verdict.txt", "r", encoding="utf-8") as f:
    raw_text = f.read()

# %%
import torch
print("Pytorch version : ", torch.__version__)
dataloader = create_dataloader_v1(
    raw_text, batch_size = 1, max_length = 4, stride = 1, shuffle = False
)
data_iter = iter(dataloader)
first_batch = next(data_iter)
print(first_batch)
# Out:
# Pytorch version :  2.10.0
# [tensor([[  40,  367, 2885, 1464]]), tensor([[ 367, 2885, 1464, 1807]])]

# %%
second_batch = next(data_iter)
print(second_batch)
# Out:
# [tensor([[ 367, 2885, 1464, 1807]]), tensor([[2885, 1464, 1807, 3619]])]

# %%
dataloader = create_dataloader_v1(
    raw_text, batch_size = 8, max_length = 4, stride = 4, shuffle = False
)
data_iter = iter(dataloader)
inputs, targets = next(data_iter)
print("Inputs : \n", inputs)
print("\nTargets : \n", targets)
# Out:
# Inputs :
#  tensor([[   40,   367,  2885,  1464],
#         [ 1807,  3619,   402,   271],
#         [10899,  2138,   257,  7026],
#         [15632,   438,  2016,   257],
#         [  922,  5891,  1576,   438],
#         [  568,   340,   373,   645],
#         [ 1049,  5975,   284,   502],
#         [  284,  3285,   326,    11]])
#
# Targets :
#  tensor([[  367,  2885,  1464,  1807],
#         [ 3619,   402,   271, 10899],
#         [ 2138,   257,  7026, 15632],
#         [  438,  2016,   257,   922],
#         [ 5891,  1576,   438,   568],
#         [  340,   373,   645,  1049],
#         [ 5975,   284,   502,   284],
#         [ 3285,   326,    11,   287]])
